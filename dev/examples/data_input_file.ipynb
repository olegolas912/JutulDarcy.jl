# %% [markdown]
# # Simulating Eclipse/DATA input files
# The DATA format is commonly used in reservoir simulation. JutulDarcy can set
# up cases on this format and includes a fully featured grid builder for
# corner-point grids. Once a case has been set up, it uses the same types as a
# regular JutulDarcy simulation, allowing modification and use of the case in
# differentiable workflows.
#
# We begin by loading the SPE9 dataset via the GeoEnergyIO package.

# %%
using JutulDarcy
pth = JutulDarcy.GeoEnergyIO.test_input_file_path("spe9", "SPE9_CP.DATA", base = "opm-tests")
# Out:
# "/home/runner/.julia/packages/GeoEnergyIO/63GkJ/src/../test/data/opm-tests/spe9/SPE9_CP.DATA"

# %% [markdown]
# ## Set up and run a simulation
# If we do not need the case, we could also have done:
# ws, states = simulate_data_file(pth)

# %%
case = setup_case_from_data_file(pth)
ws, states = simulate_reservoir(case)
# Out:
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps   2%  ETA: 0:04:46
#   Progress:  Solving step 2/90 (2.22% of time interval complete)
#   Stats:     18 iterations in 5.08 s (282.10 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps   4%  ETA: 0:02:34
#   Progress:  Solving step 4/90 (4.44% of time interval complete)
#   Stats:     32 iterations in 5.72 s (178.84 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  10%  ETA: 0:01:10
#   Progress:  Solving step 9/90 (10.00% of time interval complete)
#   Stats:     50 iterations in 6.32 s (126.34 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  15%  ETA: 0:00:46
#   Progress:  Solving step 14/90 (15.56% of time interval complete)
#   Stats:     68 iterations in 6.94 s (102.13 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  20%  ETA: 0:00:36
#   Progress:  Solving step 18/90 (20.00% of time interval complete)
#   Stats:     83 iterations in 7.45 s (89.77 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  25%  ETA: 0:00:28
#   Progress:  Solving step 23/90 (25.56% of time interval complete)
#   Stats:     98 iterations in 7.96 s (81.20 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  31%  ETA: 0:00:22
#   Progress:  Solving step 28/90 (31.11% of time interval complete)
#   Stats:     113 iterations in 8.49 s (75.14 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  36%  ETA: 0:00:19
#   Progress:  Solving step 33/90 (36.67% of time interval complete)
#   Stats:     138 iterations in 9.35 s (67.77 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  41%  ETA: 0:00:17
#   Progress:  Solving step 37/90 (41.11% of time interval complete)
#   Stats:     156 iterations in 10.02 s (64.21 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  43%  ETA: 0:00:16
#   Progress:  Solving step 39/90 (43.33% of time interval complete)
#   Stats:     175 iterations in 10.68 s (61.01 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  46%  ETA: 0:00:15
#   Progress:  Solving step 42/90 (46.67% of time interval complete)
#   Stats:     196 iterations in 11.39 s (58.11 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  49%  ETA: 0:00:14
#   Progress:  Solving step 45/90 (50.00% of time interval complete)
#   Stats:     211 iterations in 11.92 s (56.50 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  55%  ETA: 0:00:11
#   Progress:  Solving step 50/90 (55.56% of time interval complete)
#   Stats:     226 iterations in 12.45 s (55.08 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  60%  ETA: 0:00:09
#   Progress:  Solving step 55/90 (61.11% of time interval complete)
#   Stats:     241 iterations in 12.97 s (53.81 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  67%  ETA: 0:00:07
#   Progress:  Solving step 61/90 (67.78% of time interval complete)
#   Stats:     257 iterations in 13.53 s (52.63 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  76%  ETA: 0:00:05
#   Progress:  Solving step 69/90 (76.67% of time interval complete)
#   Stats:     274 iterations in 14.09 s (51.42 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  85%  ETA: 0:00:03
#   Progress:  Solving step 77/90 (85.56% of time interval complete)
#   Stats:     290 iterations in 14.59 s (50.33 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps  93%  ETA: 0:00:01
#   Progress:  Solving step 85/90 (94.44% of time interval complete)
#   Stats:     308 iterations in 15.20 s (49.35 ms each)
#
# Simulating 2 years, 24 weeks, 1.515 day as 90 report steps 100% Time: 0:00:16
#   Progress:  Solved step 90/90
#   Stats:     320 iterations in 15.58 s (48.69 ms each)
# ╭────────────────┬──────────┬───────────────┬──────────┬──────────╮
# │ Iteration type │ Avg/step │  Avg/ministep │ Time per │    Total │
# │                │ 90 steps │ 102 ministeps │       ms │ (wasted) │
# ├────────────────┼──────────┼───────────────┼──────────┼──────────┤
# │ Newton         │  3.55556 │       3.13725 │  48.6862 │  320 (0) │
# │ Linearization  │  4.68889 │       4.13725 │  36.9184 │  422 (0) │
# │ Linear solver  │  18.1222 │       15.9902 │   9.5522 │ 1631 (0) │
# ╰────────────────┴──────────┴───────────────┴──────────┴──────────╯
# ╭────────────────┬─────────┬────────────┬─────────╮
# │ Timing type    │    Each │   Relative │   Total │
# │                │      ms │ Percentage │       s │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Properties     │  2.5591 │     5.26 % │  0.8189 │
# │ Equations      │  8.8442 │    23.96 % │  3.7323 │
# │ Assembly       │  3.1054 │     8.41 % │  1.3105 │
# │ Linear solve   │ 13.6469 │    28.03 % │  4.3670 │
# │ Preconditioner │ 10.9481 │    22.49 % │  3.5034 │
# │ Update         │  1.8942 │     3.89 % │  0.6061 │
# │ Convergence    │  1.5881 │     4.30 % │  0.6702 │
# │ Input/Output   │  0.3798 │     0.25 % │  0.0387 │
# │ Other          │  1.6639 │     3.42 % │  0.5325 │
# ├────────────────┼─────────┼────────────┼─────────┤
# │ Total          │ 48.6862 │   100.00 % │ 15.5796 │
# ╰────────────────┴─────────┴────────────┴─────────╯
# ReservoirSimResult with 90 entries:
#
#   wells (26 present):
#     :INJE1
#     :PRODU25
#     :PRODU16
#     :PRODU20
#     :PRODU10
#     :PRODU12
#     :PRODU22
#     :PRODU14
#     :PRODU6
#     :PRODU7
#     :PRODU9
#     :PRODU24
#     :PRODU3
#     :PRODU23
#     :PRODU5
#     :PRODU11
#     :PRODU17
#     :PRODU4
#     :PRODU15
#     :PRODU2
#     :PRODU19
#     :PRODU21
#     :PRODU13
#     :PRODU8
#     :PRODU26
#     :PRODU18
#     Results per well:
#        :lrat => Vector{Float64} of size (90,)
#        :wrat => Vector{Float64} of size (90,)
#        :orat => Vector{Float64} of size (90,)
#        :control => Vector{Symbol} of size (90,)
#        :bhp => Vector{Float64} of size (90,)
#        :mass_rate => Vector{Float64} of size (90,)
#        :rate => Vector{Float64} of size (90,)
#        :grat => Vector{Float64} of size (90,)
#
#   states (Vector with 90 entries, reservoir variables for each state)
#     :BlackOilUnknown => Vector{BlackOilX{Float64}} of size (9000,)
#     :Saturations => Matrix{Float64} of size (3, 9000)
#     :Pressure => Vector{Float64} of size (9000,)
#     :Rs => Vector{Float64} of size (9000,)
#     :ImmiscibleSaturation => Vector{Float64} of size (9000,)
#     :TotalMasses => Matrix{Float64} of size (3, 9000)
#
#   time (report time for each state)
#      Vector{Float64} of length 90
#
#   result (extended states, reports)
#      SimResult with 90 entries
#
#   extra
#      Dict{Any, Any} with keys :simulator, :config
#
#   Completed at Apr. 04 2024 17:04 after 15 seconds, 540 milliseconds, 837.3 microseconds.

# %% [markdown]
# ## Show the input data
# The input data takes the form of a Dict:

# %%
case.input_data
# Out:
# Dict{String, Any} with 6 entries:
#   "RUNSPEC"  => OrderedDict{String, Any}("TITLE"=>"SPE 9", "DIMENS"=>[24, 25, 1…
#   "GRID"     => OrderedDict{String, Any}("cartDims"=>(24, 25, 15), "CURRENT_BOX…
#   "PROPS"    => OrderedDict{String, Any}("PVTW"=>Any[[2.48211e7, 1.0034, 4.3511…
#   "SUMMARY"  => OrderedDict{String, Any}()
#   "SCHEDULE" => Dict{String, Any}("STEPS"=>OrderedDict{String, Any}[OrderedDict…
#   "SOLUTION" => OrderedDict{String, Any}("EQUIL"=>Any[[2753.87, 2.48211e7, 3032…

# %% [markdown]
# We can also examine the RUNSPEC section

# %%
case.input_data["RUNSPEC"]
# Out:
# OrderedCollections.OrderedDict{String, Any} with 14 entries:
#   "TITLE"    => "SPE 9"
#   "DIMENS"   => [24, 25, 15]
#   "OIL"      => true
#   "WATER"    => true
#   "GAS"      => true
#   "DISGAS"   => true
#   "FIELD"    => true
#   "START"    => DateTime("2015-01-01T00:00:00")
#   "WELLDIMS" => [26, 5, 1, 26, 5, 10, 5, 4, 3, 0, 1, 1, 10, 201]
#   "TABDIMS"  => [1, 1, 40, 20, 1, 20, 20, 1, 1, -1  …  -1, 10, 10, 10, -1, 5, 5…
#   "EQLDIMS"  => [1, 100, 50, 1, 50]
#   "UNIFIN"   => true
#   "UNIFOUT"  => true
#   "MINPV"    => 2.83168e-8

# %% [markdown]
# ## Plot the simulation model
# These plot are interactive when run outside of the documentations.

# %%
using GLMakie
plot_reservoir(case.model, states)
# Out:
# Figure()

# %% [markdown]
# ## Plot the well responses

# %%
plot_well_results(ws)
# Out:
# Figure()

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
